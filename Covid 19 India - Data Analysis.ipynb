# %% [markdown]
# # Covid_19 India

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# ## Read CSV file

# %%
df1 = pd.read_csv(r"E:\Project Data Science\Covid_19\raw_data1.csv")

# %%
df1
# Out:
#        Patient Number State Patient Number Date Announced  \
# 0                 1.0             KL-TS-P1     30/01/2020
# 1                 2.0             KL-AL-P1     02/02/2020
# 2                 3.0             KL-KS-P1     03/02/2020
# 3                 4.0                DL-P1     02/03/2020
# 4                 5.0                TS-P1     02/03/2020
# ...               ...                  ...            ...
# 17359             NaN                  NaN     16/04/2020
# 17360             NaN                  NaN     18/04/2020
# 17361             NaN                  NaN     18/04/2020
# 17362             NaN                  NaN     19/04/2020
# 17363             NaN                  NaN     19/04/2020
#
#        Estimated Onset Date Age Bracket Gender             Detected City  \
# 0                       NaN          20      F                  Thrissur
# 1                       NaN         NaN    NaN                 Alappuzha
# 2                       NaN         NaN    NaN                 Kasaragod
# 3                       NaN          45      M  East Delhi (Mayur Vihar)
# 4                       NaN          24      M                 Hyderabad
# ...                     ...         ...    ...                       ...
# 17359                   NaN         NaN    NaN                       NaN
# 17360                   NaN         NaN    NaN                       NaN
# 17361                   NaN         NaN    NaN                       NaN
# 17362                   NaN         NaN    NaN                       NaN
# 17363                   NaN         NaN    NaN                       NaN
#
#       Detected District Detected State State code  ...  \
# 0              Thrissur         Kerala         KL  ...
# 1             Alappuzha         Kerala         KL  ...
# 2             Kasaragod         Kerala         KL  ...
# 3            East Delhi          Delhi         DL  ...
# 4             Hyderabad      Telangana         TG  ...
# ...                 ...            ...        ...  ...
# 17359               NaN    Maharashtra         MH  ...
# 17360            Nagpur    Maharashtra         MH  ...
# 17361               NaN    Maharashtra         MH  ...
# 17362            Nagpur    Maharashtra         MH  ...
# 17363               NaN    Maharashtra         MH  ...
#
#                                                    Notes  \
# 0                                   Travelled from Wuhan
# 1                                   Travelled from Wuhan
# 2                                   Travelled from Wuhan
# 3                          Travelled from Austria, Italy
# 4      Travelled from Dubai to Bangalore on 20th Feb,...
# ...                                                  ...
# 17359                      Correction for district count
# 17360                      Correction for district count
# 17361                      Correction for district count
# 17362                      Correction for district count
# 17363                      Correction for district count
#
#       Contracted from which Patient (Suspected) Nationality  \
# 0                                           NaN       India
# 1                                           NaN       India
# 2                                           NaN       India
# 3                                           NaN       India
# 4                                           NaN       India
# ...                                         ...         ...
# 17359                                       NaN         NaN
# 17360                                       NaN         NaN
# 17361                                       NaN         NaN
# 17362                                       NaN         NaN
# 17363                                       NaN         NaN
#
#       Type of transmission Status Change Date  \
# 0                 Imported         14/02/2020
# 1                 Imported         14/02/2020
# 2                 Imported         14/02/2020
# 3                 Imported         15/03/2020
# 4                 Imported         02/03/2020
# ...                    ...                ...
# 17359                  NaN                NaN
# 17360                  NaN                NaN
# 17361                  NaN                NaN
# 17362                  NaN                NaN
# 17363                  NaN                NaN
#
#                                                 Source_1  \
# 0      https://twitter.com/vijayanpinarayi/status/122...
# 1      https://www.indiatoday.in/india/story/kerala-r...
# 2      https://www.indiatoday.in/india/story/kerala-n...
# 3      https://www.indiatoday.in/india/story/not-a-ja...
# 4      https://www.deccanherald.com/national/south/qu...
# ...                                                  ...
# 17359                                                NaN
# 17360                                                NaN
# 17361                                                NaN
# 17362                                                NaN
# 17363                                                NaN
#
#                                                 Source_2  \
# 0      https://weather.com/en-IN/india/news/news/2020...
# 1      https://weather.com/en-IN/india/news/news/2020...
# 2      https://twitter.com/ANI/status/122422148580539...
# 3      https://economictimes.indiatimes.com/news/poli...
# 4      https://www.indiatoday.in/india/story/coronavi...
# ...                                                  ...
# 17359                                                NaN
# 17360                                                NaN
# 17361                                                NaN
# 17362                                                NaN
# 17363                                                NaN
#
#                                                 Source_3  \
# 0                                                    NaN
# 1                                                    NaN
# 2      https://weather.com/en-IN/india/news/news/2020...
# 3                                                    NaN
# 4      https://www.thehindu.com/news/national/coronav...
# ...                                                  ...
# 17359                                                NaN
# 17360                                                NaN
# 17361                                                NaN
# 17362                                                NaN
# 17363                                                NaN
#
#                                      Backup Notes Num Cases
# 0                              Student from Wuhan         1
# 1                              Student from Wuhan         1
# 2                              Student from Wuhan         1
# 3             Travel history to Italy and Austria         1
# 4      Travel history to Dubai, Singapore contact         1
# ...                                           ...       ...
# 17359                                         NaN        -2
# 17360                                         NaN         1
# 17361                                         NaN        -1
# 17362                                         NaN        10
# 17363                                         NaN       -10
#
# [17364 rows x 21 columns]

# %%
df2 = pd.read_csv(r"E:\Project Data Science\Covid_19\raw_data2.csv")
df3 = pd.read_csv(r"E:\Project Data Science\Covid_19\raw_data3.csv")
df4 = pd.read_csv(r"E:\Project Data Science\Covid_19\raw_data4.csv")
df5 = pd.read_csv(r"E:\Project Data Science\Covid_19\raw_data5.csv")
df6 = pd.read_csv(r"E:\Project Data Science\Covid_19\raw_data6.csv")
df7 = pd.read_csv(r"E:\Project Data Science\Covid_19\raw_data7.csv")
df8 = pd.read_csv(r"E:\Project Data Science\Covid_19\raw_data8.csv")
df9 = pd.read_csv(r"E:\Project Data Science\Covid_19\raw_data9.csv")
df10 = pd.read_csv(r"E:\Project Data Science\Covid_19\raw_data10.csv")
df11 = pd.read_csv(r"E:\Project Data Science\Covid_19\raw_data11.csv")
df12 = pd.read_csv(r"E:\Project Data Science\Covid_19\raw_data12.csv")
df13 = pd.read_csv(r"E:\Project Data Science\Covid_19\raw_data13.csv")
df14 = pd.read_csv(r"E:\Project Data Science\Covid_19\raw_data14.csv")
df15 = pd.read_csv(r"E:\Project Data Science\Covid_19\raw_data15.csv")
df16 = pd.read_csv(r"E:\Project Data Science\Covid_19\raw_data16.csv")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17364 entries, 0 to 17363
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Patient Number                             17306 non-null  float64
#  1   State Patient Number                       2457 non-null   object
#  2   Date Announced                             17364 non-null  object
#  3   Estimated Onset Date                       0 non-null      float64
#  4   Age Bracket                                1670 non-null   object
#  5   Gender                                     3746 non-null   object
#  6   Detected City                              2166 non-null   object
#  7   Detected District                          14978 non-null  object
#  8   Detected State                             17363 non-null  object
#  9   State code                                 17363 non-null  object
#  10  Current Status                             17364 non-null  object
#  11  Notes                                      16046 non-null  object
#  12  Contracted from which Patient (Suspected)  1537 non-null   object
#  13  Nationality                                1554 non-null   object
#  14  Type of transmission                       2951 non-null   object
#  15  Status Change Date                         17195 non-null  object
#  16  Source_1                                   17075 non-null  object
#  17  Source_2                                   3396 non-null   object
#  18  Source_3                                   445 non-null    object
#  19  Backup Notes                               361 non-null    object
#  20  Num Cases                                  17364 non-null  int64
# dtypes: float64(2), int64(1), object(18)
# memory usage: 2.8+ MB

# %% [markdown]
# ## Check all the Columns

# %%
df1.columns
# Out:
# Index(['Patient Number', 'State Patient Number', 'Date Announced',
#        'Estimated Onset Date', 'Age Bracket', 'Gender', 'Detected City',
#        'Detected District', 'Detected State', 'State code', 'Current Status',
#        'Notes', 'Contracted from which Patient (Suspected)', 'Nationality',
#        'Type of transmission', 'Status Change Date', 'Source_1', 'Source_2',
#        'Source_3', 'Backup Notes', 'Num Cases'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['Entry_ID', 'State Patient Number', 'Date Announced', 'Age Bracket',
#        'Gender', 'Detected City', 'Detected District', 'Detected State',
#        'State code', 'Num Cases', 'Current Status',
#        'Contracted from which Patient (Suspected)', 'Notes', 'Source_1',
#        'Source_2', 'Source_3', 'Nationality', 'Type of transmission',
#        'Status Change Date', 'Patient Number'],
#       dtype='object')

# %% [markdown]
# ## Retain Necessary Columns

# %%
df1 = df1.loc[:,['Num Cases','Date Announced','Age Bracket','Gender','Detected City','Detected District','Detected State','Current Status']]
df2 = df2.loc[:,['Num Cases','Date Announced','Age Bracket','Gender','Detected City','Detected District','Detected State','Current Status']]
df3 = df3.loc[:,['Num Cases','Date Announced','Age Bracket','Gender','Detected City','Detected District','Detected State','Current Status']]
df4 = df4.loc[:,['Num Cases','Date Announced','Age Bracket','Gender','Detected City','Detected District','Detected State','Current Status']]
df5 = df5.loc[:,['Num Cases','Date Announced','Age Bracket','Gender','Detected City','Detected District','Detected State','Current Status']]
df6 = df6.loc[:,['Num Cases','Date Announced','Age Bracket','Gender','Detected City','Detected District','Detected State','Current Status']]
df7 = df7.loc[:,['Num Cases','Date Announced','Age Bracket','Gender','Detected City','Detected District','Detected State','Current Status']]
df8 = df8.loc[:,['Num Cases','Date Announced','Age Bracket','Gender','Detected City','Detected District','Detected State','Current Status']]
df9 = df9.loc[:,['Num Cases','Date Announced','Age Bracket','Gender','Detected City','Detected District','Detected State','Current Status']]
df10 = df10.loc[:,['Num Cases','Date Announced','Age Bracket','Gender','Detected City','Detected District','Detected State','Current Status']]
df11 = df11.loc[:,['Num Cases','Date Announced','Age Bracket','Gender','Detected City','Detected District','Detected State','Current Status']]
df12 = df12.loc[:,['Num Cases','Date Announced','Age Bracket','Gender','Detected City','Detected District','Detected State','Current Status']]
df13 = df13.loc[:,['Num Cases','Date Announced','Age Bracket','Gender','Detected City','Detected District','Detected State','Current Status']]
df14 = df14.loc[:,['Num Cases','Date Announced','Age Bracket','Gender','Detected City','Detected District','Detected State','Current Status']]
df15 = df15.loc[:,['Num Cases','Date Announced','Age Bracket','Gender','Detected City','Detected District','Detected State','Current Status']]
df16 = df16.loc[:,['Num Cases','Date Announced','Age Bracket','Gender','Detected City','Detected District','Detected State','Current Status']]

# %%
df = df1.append([df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16])
df
# Out:
#        Num Cases Date Announced Age Bracket Gender             Detected City  \
# 0            1.0     30/01/2020          20      F                  Thrissur
# 1            1.0     02/02/2020         NaN    NaN                 Alappuzha
# 2            1.0     03/02/2020         NaN    NaN                 Kasaragod
# 3            1.0     02/03/2020          45      M  East Delhi (Mayur Vihar)
# 4            1.0     02/03/2020          24      M                 Hyderabad
# ...          ...            ...         ...    ...                       ...
# 26620       29.0     08/10/2020         NaN    NaN                       NaN
# 26621       10.0     08/10/2020         NaN    NaN                       NaN
# 26622       -8.0     08/10/2020         NaN    NaN                       NaN
# 26623        8.0     08/10/2020         NaN    NaN                       NaN
# 26624      -27.0     08/10/2020         NaN    NaN                       NaN
#
#       Detected District    Detected State  Current Status
# 0              Thrissur            Kerala       Recovered
# 1             Alappuzha            Kerala       Recovered
# 2             Kasaragod            Kerala       Recovered
# 3            East Delhi             Delhi       Recovered
# 4             Hyderabad         Telangana       Recovered
# ...                 ...               ...             ...
# 26620               Leh            Ladakh       Recovered
# 26621            Kargil            Ladakh       Recovered
# 26622             Solan  Himachal Pradesh  Migrated_Other
# 26623             Solan  Himachal Pradesh       Recovered
# 26624            Ribhoi         Meghalaya    Hospitalized
#
# [353033 rows x 8 columns]

# %% [markdown]
# ## Date Split

# %%
date = df['Date Announced'].str.split("/",expand = True)
date.columns=['Day','Month','Year']
date
# Out:
#       Day Month  Year
# 0      30    01  2020
# 1      02    02  2020
# 2      03    02  2020
# 3      02    03  2020
# 4      02    03  2020
# ...    ..   ...   ...
# 26620  08    10  2020
# 26621  08    10  2020
# 26622  08    10  2020
# 26623  08    10  2020
# 26624  08    10  2020
#
# [353033 rows x 3 columns]

# %% [markdown]
# ## Add date to the data

# %%
df = pd.concat([df,date], axis = 1)
df
# Out:
#        Num Cases Date Announced Age Bracket Gender             Detected City  \
# 0            1.0     30/01/2020          20      F                  Thrissur
# 1            1.0     02/02/2020         NaN    NaN                 Alappuzha
# 2            1.0     03/02/2020         NaN    NaN                 Kasaragod
# 3            1.0     02/03/2020          45      M  East Delhi (Mayur Vihar)
# 4            1.0     02/03/2020          24      M                 Hyderabad
# ...          ...            ...         ...    ...                       ...
# 26620       29.0     08/10/2020         NaN    NaN                       NaN
# 26621       10.0     08/10/2020         NaN    NaN                       NaN
# 26622       -8.0     08/10/2020         NaN    NaN                       NaN
# 26623        8.0     08/10/2020         NaN    NaN                       NaN
# 26624      -27.0     08/10/2020         NaN    NaN                       NaN
#
#       Detected District    Detected State  Current Status Day Month  Year
# 0              Thrissur            Kerala       Recovered  30    01  2020
# 1             Alappuzha            Kerala       Recovered  02    02  2020
# 2             Kasaragod            Kerala       Recovered  03    02  2020
# 3            East Delhi             Delhi       Recovered  02    03  2020
# 4             Hyderabad         Telangana       Recovered  02    03  2020
# ...                 ...               ...             ...  ..   ...   ...
# 26620               Leh            Ladakh       Recovered  08    10  2020
# 26621            Kargil            Ladakh       Recovered  08    10  2020
# 26622             Solan  Himachal Pradesh  Migrated_Other  08    10  2020
# 26623             Solan  Himachal Pradesh       Recovered  08    10  2020
# 26624            Ribhoi         Meghalaya    Hospitalized  08    10  2020
#
# [353033 rows x 11 columns]

# %% [markdown]
# ## Save All the data to CSV

# %%
df.to_csv("Covid_19.csv")

# %%
df
# Out:
#        Num Cases Date Announced Age Bracket Gender             Detected City  \
# 0            1.0     30/01/2020          20      F                  Thrissur
# 1            1.0     02/02/2020         NaN    NaN                 Alappuzha
# 2            1.0     03/02/2020         NaN    NaN                 Kasaragod
# 3            1.0     02/03/2020          45      M  East Delhi (Mayur Vihar)
# 4            1.0     02/03/2020          24      M                 Hyderabad
# ...          ...            ...         ...    ...                       ...
# 26620       29.0     08/10/2020         NaN    NaN                       NaN
# 26621       10.0     08/10/2020         NaN    NaN                       NaN
# 26622       -8.0     08/10/2020         NaN    NaN                       NaN
# 26623        8.0     08/10/2020         NaN    NaN                       NaN
# 26624      -27.0     08/10/2020         NaN    NaN                       NaN
#
#       Detected District    Detected State  Current Status Day Month  Year
# 0              Thrissur            Kerala       Recovered  30    01  2020
# 1             Alappuzha            Kerala       Recovered  02    02  2020
# 2             Kasaragod            Kerala       Recovered  03    02  2020
# 3            East Delhi             Delhi       Recovered  02    03  2020
# 4             Hyderabad         Telangana       Recovered  02    03  2020
# ...                 ...               ...             ...  ..   ...   ...
# 26620               Leh            Ladakh       Recovered  08    10  2020
# 26621            Kargil            Ladakh       Recovered  08    10  2020
# 26622             Solan  Himachal Pradesh  Migrated_Other  08    10  2020
# 26623             Solan  Himachal Pradesh       Recovered  08    10  2020
# 26624            Ribhoi         Meghalaya    Hospitalized  08    10  2020
#
# [353033 rows x 11 columns]

# %% [markdown]
# ## Inspect the Data Frame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 353033 entries, 0 to 26624
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Num Cases          353025 non-null  float64
#  1   Date Announced     353029 non-null  object
#  2   Age Bracket        115025 non-null  object
#  3   Gender             117456 non-null  object
#  4   Detected City      14206 non-null   object
#  5   Detected District  342392 non-null  object
#  6   Detected State     353020 non-null  object
#  7   Current Status     353029 non-null  object
#  8   Day                353029 non-null  object
#  9   Month              353029 non-null  object
#  10  Year               353029 non-null  object
# dtypes: float64(1), object(10)
# memory usage: 32.3+ MB

# %%
data = df

# %%
data
# Out:
#        Num Cases Date Announced Age Bracket Gender             Detected City  \
# 0            1.0     30/01/2020          20      F                  Thrissur
# 1            1.0     02/02/2020         NaN    NaN                 Alappuzha
# 2            1.0     03/02/2020         NaN    NaN                 Kasaragod
# 3            1.0     02/03/2020          45      M  East Delhi (Mayur Vihar)
# 4            1.0     02/03/2020          24      M                 Hyderabad
# ...          ...            ...         ...    ...                       ...
# 26620       29.0     08/10/2020         NaN    NaN                       NaN
# 26621       10.0     08/10/2020         NaN    NaN                       NaN
# 26622       -8.0     08/10/2020         NaN    NaN                       NaN
# 26623        8.0     08/10/2020         NaN    NaN                       NaN
# 26624      -27.0     08/10/2020         NaN    NaN                       NaN
#
#       Detected District    Detected State  Current Status Day Month  Year
# 0              Thrissur            Kerala       Recovered  30    01  2020
# 1             Alappuzha            Kerala       Recovered  02    02  2020
# 2             Kasaragod            Kerala       Recovered  03    02  2020
# 3            East Delhi             Delhi       Recovered  02    03  2020
# 4             Hyderabad         Telangana       Recovered  02    03  2020
# ...                 ...               ...             ...  ..   ...   ...
# 26620               Leh            Ladakh       Recovered  08    10  2020
# 26621            Kargil            Ladakh       Recovered  08    10  2020
# 26622             Solan  Himachal Pradesh  Migrated_Other  08    10  2020
# 26623             Solan  Himachal Pradesh       Recovered  08    10  2020
# 26624            Ribhoi         Meghalaya    Hospitalized  08    10  2020
#
# [353033 rows x 11 columns]

# %%
round(data.isnull().sum(axis = 0).sort_values(ascending=False)/len(data)*100,2)
# Out:
# Detected City        95.98
# Age Bracket          67.42
# Gender               66.73
# Detected District     3.01
# Detected State        0.00
# Num Cases             0.00
# Year                  0.00
# Month                 0.00
# Day                   0.00
# Current Status        0.00
# Date Announced        0.00
# dtype: float64

# %%
data.isnull().sum(axis = 1).sort_values(ascending = False)
# Out:
# 29044    11
# 24246    11
# 27345    10
# 27344    10
# 12586     6
#          ..
# 5334      0
# 5335      0
# 5336      0
# 5337      0
# 0         0
# Length: 353033, dtype: int64

# %% [markdown]
# ## Total Covid cases per Month

# %%
m = data[data['Current Status'] == 'Hospitalized'].groupby('Month')['Num Cases'].sum()
m
# Out:
# Month
# 03       1431.0
# 04      33209.0
# 05     155781.0
# 06     395144.0
# 07    1111262.0
# 08    1990886.0
# 09    2622324.0
# 10     593521.0
# Name: Num Cases, dtype: float64

# %%
m.plot.bar()
plt.show()

# %% [markdown]
# ## Total Male/Female Infected with Coronavirus

# %%
data
# Out:
#        Num Cases Date Announced Age Bracket Gender             Detected City  \
# 0            1.0     30/01/2020          20      F                  Thrissur
# 1            1.0     02/02/2020         NaN    NaN                 Alappuzha
# 2            1.0     03/02/2020         NaN    NaN                 Kasaragod
# 3            1.0     02/03/2020          45      M  East Delhi (Mayur Vihar)
# 4            1.0     02/03/2020          24      M                 Hyderabad
# ...          ...            ...         ...    ...                       ...
# 26620       29.0     08/10/2020         NaN    NaN                       NaN
# 26621       10.0     08/10/2020         NaN    NaN                       NaN
# 26622       -8.0     08/10/2020         NaN    NaN                       NaN
# 26623        8.0     08/10/2020         NaN    NaN                       NaN
# 26624      -27.0     08/10/2020         NaN    NaN                       NaN
#
#       Detected District    Detected State  Current Status Day Month  Year
# 0              Thrissur            Kerala       Recovered  30    01  2020
# 1             Alappuzha            Kerala       Recovered  02    02  2020
# 2             Kasaragod            Kerala       Recovered  03    02  2020
# 3            East Delhi             Delhi       Recovered  02    03  2020
# 4             Hyderabad         Telangana       Recovered  02    03  2020
# ...                 ...               ...             ...  ..   ...   ...
# 26620               Leh            Ladakh       Recovered  08    10  2020
# 26621            Kargil            Ladakh       Recovered  08    10  2020
# 26622             Solan  Himachal Pradesh  Migrated_Other  08    10  2020
# 26623             Solan  Himachal Pradesh       Recovered  08    10  2020
# 26624            Ribhoi         Meghalaya    Hospitalized  08    10  2020
#
# [353033 rows x 11 columns]

# %%
data.groupby('Gender')['Num Cases'].sum().sort_values(ascending = False)
# Out:
# Gender
# M             77750.0
# F             41071.0
# Non-Binary       18.0
# M,                1.0
# M                 1.0
# Femal e           1.0
# Name: Num Cases, dtype: float64

# %% [markdown]
# ## Which Age group is affected the Most

# %%
M = data.groupby('Age Bracket')['Num Cases'].sum().sort_values(ascending = False).head(10)
M
# Out:
# Age Bracket
# 30.0    1931.0
# 30      1789.0
# 40.0    1733.0
# 35      1675.0
# 35.0    1647.0
# 40      1623.0
# 45.0    1617.0
# 32.0    1554.0
# 45      1546.0
# 25      1544.0
# Name: Num Cases, dtype: float64

# %%
M.plot.bar(figsize = (16,5))
plt.show()

# %% [markdown]
# ## Check which state has maximum number of cases

# %%
data.groupby('Detected State')['Num Cases'].sum().sort_values()
# Out:
# Detected State
# State Unassigned                                  0.0
# Mizoram                                        4076.0
# Sikkim                                         5948.0
# Dadra and Nagar Haveli and Daman and Diu       6153.0
# Andaman and Nicobar Islands                    7703.0
# Ladakh                                         8499.0
# Meghalaya                                     12152.0
# Nagaland                                      12323.0
# Arunachal Pradesh                             20179.0
# Manipur                                       22479.0
# Chandigarh                                    24435.0
# Himachal Pradesh                              30589.0
# Tripura                                       51123.0
# Puducherry                                    56347.0
# Goa                                           69481.0
# Uttarakhand                                   98843.0
# Jammu and Kashmir                            151961.0
# Jharkhand                                    171684.0
# Punjab                                       232555.0
# Chhattisgarh                                 241765.0
# Haryana                                      266295.0
# Madhya Pradesh                               266851.0
# Gujarat                                      279050.0
# Rajasthan                                    283158.0
# Assam                                        352001.0
# Bihar                                        373900.0
# Telangana                                    386579.0
# Kerala                                       426777.0
# Odisha                                       462117.0
# West Bengal                                  539081.0
# Delhi                                        578503.0
# Uttar Pradesh                                812013.0
# Tamil Nadu                                  1236405.0
# Karnataka                                   1241368.0
# Andhra Pradesh                              1430515.0
# Maharashtra                                 2744252.0
# Name: Num Cases, dtype: float64

# %%
p =data[data['Current Status'] == 'Hospitalized'].groupby('Detected State')['Num Cases'].sum().sort_values(ascending = False)
p
# Out:
# Detected State
# Maharashtra                                 1493870.0
# Andhra Pradesh                               739717.0
# Karnataka                                    679284.0
# Tamil Nadu                                   640936.0
# Uttar Pradesh                                427450.0
# Delhi                                        300829.0
# West Bengal                                  284024.0
# Kerala                                       258790.0
# Odisha                                       244141.0
# Telangana                                    206642.0
# Bihar                                        192670.0
# Assam                                        191397.0
# Rajasthan                                    152601.0
# Gujarat                                      147945.0
# Madhya Pradesh                               142020.0
# Haryana                                      138670.0
# Chhattisgarh                                 134604.0
# Punjab                                       121714.0
# Jharkhand                                     90486.0
# Jammu and Kashmir                             81792.0
# Uttarakhand                                   53358.0
# Goa                                           37102.0
# Puducherry                                    30539.0
# Tripura                                       27756.0
# Himachal Pradesh                              16776.0
# Chandigarh                                    12922.0
# Manipur                                       12678.0
# Arunachal Pradesh                             11479.0
# Meghalaya                                      7261.0
# Nagaland                                       6736.0
# Ladakh                                         4902.0
# Andaman and Nicobar Islands                    3941.0
# Sikkim                                         3246.0
# Dadra and Nagar Haveli and Daman and Diu       3129.0
# Mizoram                                        2150.0
# State Unassigned                                  0.0
# Name: Num Cases, dtype: float64

# %%
p.plot.bar(figsize = (16,7))
plt.show()

# %% [markdown]
# ## How many cases Everyday?

# %%
day = data[data['Current Status'] == 'Hospitalized'].groupby(['Month','Day'])[['Num Cases']].sum()
day
# Out:
#            Num Cases
# Month Day
# 03    04         5.0
#       05         1.0
#       07         2.0
#       09         4.0
#       10         4.0
# ...              ...
# 10    04     74770.0
#       05     60130.0
#       06     71869.0
#       07     78809.0
#       08     70797.0
#
# [217 rows x 1 columns]

# %%
day.unstack(level= 0).plot(kind='bar',subplots = True,figsize = (16,25))
plt.show()

# %%
data[data['Current Status'] == 'Deceased']['Num Cases'].sum()
# Out:
# 105685.0

# %%
data
# Out:
#        Num Cases Date Announced Age Bracket Gender             Detected City  \
# 0            1.0     30/01/2020          20      F                  Thrissur
# 1            1.0     02/02/2020         NaN    NaN                 Alappuzha
# 2            1.0     03/02/2020         NaN    NaN                 Kasaragod
# 3            1.0     02/03/2020          45      M  East Delhi (Mayur Vihar)
# 4            1.0     02/03/2020          24      M                 Hyderabad
# ...          ...            ...         ...    ...                       ...
# 26620       29.0     08/10/2020         NaN    NaN                       NaN
# 26621       10.0     08/10/2020         NaN    NaN                       NaN
# 26622       -8.0     08/10/2020         NaN    NaN                       NaN
# 26623        8.0     08/10/2020         NaN    NaN                       NaN
# 26624      -27.0     08/10/2020         NaN    NaN                       NaN
#
#       Detected District    Detected State  Current Status Day Month  Year
# 0              Thrissur            Kerala       Recovered  30    01  2020
# 1             Alappuzha            Kerala       Recovered  02    02  2020
# 2             Kasaragod            Kerala       Recovered  03    02  2020
# 3            East Delhi             Delhi       Recovered  02    03  2020
# 4             Hyderabad         Telangana       Recovered  02    03  2020
# ...                 ...               ...             ...  ..   ...   ...
# 26620               Leh            Ladakh       Recovered  08    10  2020
# 26621            Kargil            Ladakh       Recovered  08    10  2020
# 26622             Solan  Himachal Pradesh  Migrated_Other  08    10  2020
# 26623             Solan  Himachal Pradesh       Recovered  08    10  2020
# 26624            Ribhoi         Meghalaya    Hospitalized  08    10  2020
#
# [353033 rows x 11 columns]

# %%
death=data[data['Current Status'] == 'Deceased'].groupby('Detected State')['Num Cases'].sum().sort_values(ascending =False)
death
# Out:
# Detected State
# Maharashtra                                 39099.0
# Tamil Nadu                                  10029.0
# Karnataka                                    9667.0
# Uttar Pradesh                                6216.0
# Andhra Pradesh                               6097.0
# Delhi                                        5600.0
# West Bengal                                  5422.0
# Punjab                                       3725.0
# Gujarat                                      3394.0
# Madhya Pradesh                               2446.0
# Rajasthan                                    1565.0
# Haryana                                      1545.0
# Jammu and Kashmir                            1286.0
# Telangana                                    1177.0
# Chhattisgarh                                 1158.0
# Odisha                                       1027.0
# Kerala                                        930.0
# Bihar                                         928.0
# Assam                                         793.0
# Jharkhand                                     772.0
# Uttarakhand                                   702.0
# Puducherry                                    556.0
# Goa                                           484.0
# Tripura                                       301.0
# Himachal Pradesh                              232.0
# Chandigarh                                    186.0
# Manipur                                        83.0
# Ladakh                                         63.0
# Meghalaya                                      59.0
# Andaman and Nicobar Islands                    55.0
# Sikkim                                         52.0
# Arunachal Pradesh                              22.0
# Nagaland                                       12.0
# Dadra and Nagar Haveli and Daman and Diu        2.0
# Name: Num Cases, dtype: float64

# %%
death.plot.bar(figsize = (16,6))
plt.show()
